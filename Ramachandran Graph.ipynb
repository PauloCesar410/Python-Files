# %%
#!pip install ramachandranplot
#!pip install matplotlib
#!pip install biopython
#!pip install numpy
#import os
import ramachandranplot as rama
pdb = "1a6b.pdb" #path of pdb file any pdb which is required to be ploted.
rama.plot_ramachandran(pdb)
