# %%
import math 
sigma = float(input("Digite um valor para sigma: "))
# Out:
# Digite um valor para sigma: 1

# %%
def mexican_hat(x):
    return ( 2/math.sqrt(3*sigma)*(math.pi)**0.25)*(1-(x/sigma)**2)*(math.exp(-x**2/2*sigma**2))

# %%
import matplotlib.pyplot as plt
x=np.linspace(-4,4)   # Comprehenssion list for values of x and y
y=[mexican_hat(i) for i in x]
#print(y)

plt.plot(x,y,color='#8B0000', label='Mexican hat wavelet')   #Ploting of graph of wavelet interpolet
plt.grid()
plt.legend()
plt.show()

print(mexican_hat(1.35))
# Out:
# -0.5083254999538257
