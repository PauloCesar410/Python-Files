# %%
import numpy as np   # Código em python para as wavelets de Daubechies de gênero 6
a=(0.4704672077841637,1.141116915831444,0.6503650005262326,-0.1909344155683274,-0.1208322083103962,0.04981749973688374) # Coeficientes de Daubechies de gênero 6
A = np.array(((a[1]-1,a[0],0,0), (a[3],a[2]-1,a[1],a[0]), (a[5], a[4], a[3]-1,a[2]),(1,1,1,1)))  # Código para descobrir os valores de phi(1), phi(2), phi(3),phi(4),phi(5), Ax=b, x=A^{-1}b.
#print("Matriz A \n",A)
b = np.array((0,0,0,1))
#print("Vetor b \n",b)
c  = np.linalg.solve(A, b)
#print("Solução de Ax=b é c = ",c)
def DB6escala(x):
    w6_escalaValor=0
    if (x==5 or x==0):
        return 0
    elif (x==1):
        return c[0]
    elif (x==2):
        return c[1]
    elif (x==3):
        return c[2]
    elif (x==4):
        return c[3]
    elif (x<0 or x>5):
        return 0
    elif (x>0 and x<5):
        for m in range(0,6):
             w6_escalaValor += a[m]*DB6escala(2*x-m)
        return w6_escalaValor
import matplotlib.pyplot as plt
x=[0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0,1.0078125,1.015625,1.03125,1.0625,1.125,1.25,1.5,1.75,2.0,2.0078125,2.015625,2.03125,2.0625,2.125,2.25,2.5,2.75,3.0,3.0078125,3.015625,3.03125,3.0625,3.125,3.25,3.5,3.75,4.0,4.0078125,4.015625,4.03125,4.0625,4.125,4.25,4.5,4.75,5.0]    #Comprehenssion list for values of x and y
y=[DB6escala(i) for i in x]
#print(y)
plt.plot(x,y,color='#0202FF', label='Função escala-DB 6')   #Plotando gráfico da função escala
plt.grid()
plt.legend()
plt.show()

# %%
#TRANSLAÇÕES DA DB6
         #Phi(x+1)
def DB6escala1(x):
    return DB6escala(x+1)
x3=[-1.0,-0.75,-0.5,-0.25,-0.125,-0.0625,-0.03125,-0.015625,-0.0078125,0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0,1.0078125,1.015625,1.03125,1.0625,1.125,1.25,1.5,1.75,2.0,2.0078125,2.015625,2.03125,2.0625,2.125,2.25,2.5,2.75,3.0,3.0078125,3.015625,3.03125,3.0625,3.125,3.25,3.5,3.75,4.0]   
y3=[DB6escala1(i) for i in x3]

        #Phi(x+2)
def DB6escala2(x):
    return DB6escala(x+2)
x4=[-2.0,-1.75,-1.50,-1.25,-1.125,-1.0625,-1.03125,-1.015625,-1.0078125,-1.0,-0.75,-0.5,-0.25,-0.125,-0.0625,-0.03125,-0.015625,-0.0078125,0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0,1.0078125,1.015625,1.03125,1.0625,1.125,1.25,1.5,1.75,2.0,2.0078125,2.015625,2.03125,2.0625,2.125,2.25,2.5,2.75,3.0]    
y4=[DB6escala2(i) for i in x4]

        #Phi(x+3)
def DB6escala3(x):
    return DB6escala(x+3)
x5=[-3.0,-2.75,-2.50,-2.25,-2.125,-2.0625,-2.03125,-2.015625,-2.0078125,-2.0,-1.75,-1.50,-1.25,-1.125,-1.0625,-1.03125,-1.015625,-1.0078125,-1.0,-0.75,-0.5,-0.25,-0.125,-0.0625,-0.03125,-0.015625,-0.0078125,0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0,1.0078125,1.015625,1.03125,1.0625,1.125,1.25,1.5,1.75,2.0]   
y5=[DB6escala3(i) for i in x5]

        #Phi(x+4)
def DB6escala4(x):
    return DB6escala(x+4)
x6=[-4.0,-3.75,-3.50,-3.25,-3.125,-3.0625,-3.03125,-3.015625,-3.0078125,-3.0,-2.75,-2.50,-2.25,-2.125,-2.0625,-2.03125,-2.015625,-2.0078125,-2.0,-1.75,-1.50,-1.25,-1.125,-1.0625,-1.03125,-1.015625,-1.0078125,-1.0,-0.75,-0.5,-0.25,-0.125,-0.0625,-0.03125,-0.015625,-0.0078125,0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0]  
y6=[DB6escala4(i) for i in x6]

        #PLOTAR GRÁFICOS DAS TRANSLAÇÕES DA DB6
import matplotlib.pyplot as plt 
plt.figure(figsize=(8,8))
plt.plot(x,y, color='#FF0202', label='DB6escala(x)')   
plt.plot(x3,y3,color='#008000', label='DB6escala(x+1)')   
plt.plot(x4,y4,color='#00468B', label='DB6escala(x+2)')  
plt.plot(x5,y5,color='#5E4800', label='DB6escala(x+3)') 
plt.plot(x6,y6,color='#FFD700', label='DB6escala(x+4)')
plt.grid()
plt.legend()
plt.show()

#------------------------------GERANDO POLINÔMIO X^2-----------------------------------------------------------

def Polinomiox2(x):
    return x**2
x7=[0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0]  
y7=[Polinomiox2(i) for i in x7]

         #Phi(x) com momento
y8=[0.6681446691385907*DB6escala(i)for i in x7]
          #Phi(x+1) com momento
y9=[0.03334233351683025*DB6escala1(i) for i in x7]
        #Phi(x+2) com momento
y10=[1.398539997895070*DB6escala2(i) for i in x7]
        #Phi(x+3) com momento
y11=[4.763737662273309*DB6escala3(i) for i in x7]
        #Phi(x+4) com momento
y12=[10.12893532665155*DB6escala4(i) for i in x7]
        #Polinômio aproximado
y13=[0.6681446691385907*DB6escala(i)+0.03334233351683025*DB6escala1(i)+1.398539997895070*DB6escala2(i)+4.763737662273309*DB6escala3(i)+10.12893532665155*DB6escala4(i) for i in x7]

plt.figure(figsize=(8,8))
#plt.plot(x7,y7, color='#FF0202', label='x^2')
plt.plot(x7,y8, color='#02ffff', label='0,6681447*DB6escala(x)')   
plt.plot(x7,y9,color='#008000', label='0,03334233*DB6escala(x+1)')   
plt.plot(x7,y10,color='#00468B', label='1,398539*DB6escala(x+2)')  
plt.plot(x7,y11,color='#5E4800', label='4,763737*DB6escala(x+3)') 
plt.plot(x7,y12,color='#FFD700', label='10,12893*DB6escala(x+4)')
plt.plot(x7,y13,color='#ff02ff',label='Função x^3 aproximada por DB 6')
plt.grid()
plt.legend()
plt.show()

# %%
import numpy as np               
import matplotlib.pyplot as plt
k=1
      #Criando função fatorial
def fatorial(n):
   fatorial = 1
   while n >= 1:
      fatorial = fatorial * n
      n = n - 1
   return fatorial
#r1=binomial(3)
#print(r1)
#print(fatorial(2))

      #Calculando o momento M(k,0)
def binomial1(m):  
    binomial1=0
    for r in range(0,m+1,1):
         binomial1 +=(1/2*(2**k - 1))*a[r]*r
         print(a[r])
    return binomial1

# %%
import numpy as np   # Código em python para as wavelets de Daubechies de gênero 8
d=(0.3258034280512984,1.010945715091829,0.8922001382467597,-0.03957502623564464,-0.2645071673690398,0.04361630047417725,0.04650360107098176,-0.01498698933036147) # Coeficientes de Daubechies de gênero 8
D = np.array(((d[1]-1,d[0],0,0,0,0), (d[3],d[2]-1,d[1],d[0],0,0), (d[5], d[4], d[3]-1,d[2],d[1],d[0]),(d[7],d[6],d[5],d[4]-1,d[3],d[2]),(0,0,d[7],d[6],d[5]-1,d[4]),(1,1,1,1,1,1)))  # Código para descobrir os valores de phi(1), phi(2), phi(3),phi(4),phi(5), Ax=b, x=A^{-1}b.
#print("Matriz D \n",D)
f = np.array((0,0,0,0,0,1))
#print("Vetor f \n",f)
g  = np.linalg.solve(D, f)
#print("Solução de dg=f é g = ",g)
def DB8escala(x):
    w8_escalaValor=0
    if (x==7 or x==0):
        return 0
    elif (x==1):
        return g[0]
    elif (x==2):
        return g[1]
    elif (x==3):
        return g[2]
    elif (x==4):
        return g[3]
    elif (x==5):
        return g[4]
    elif (x==6):
        return g[5]
    elif (x<0 or x>7):
        return 0
    elif (x>0 and x<7):
        for m in range(0,8):
             w8_escalaValor += d[m]*DB8escala(2*x-m)
        return w8_escalaValor
import matplotlib.pyplot as plt
x2=[0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0,1.0078125,1.015625,1.03125,1.0625,1.125,1.25,1.5,1.75,2.0,2.0078125,2.015625,2.03125,2.0625,2.125,2.25,2.5,2.75,3.0,3.0078125,3.015625,3.03125,3.0625,3.125,3.25,3.5,3.75,4.0,4.0078125,4.015625,4.03125,4.0625,4.125,4.25,4.5,4.75,5.0,5.0078125,5.015625,5.03125,5.0625,5.125,5.25,5.5,5.75,6.0,6.0078125,6.015625,6.03125,6.0625,6.125,6.25,6.5,6.75,7.0]    
y2=[DB8escala(i) for i in x2]
#print(y)

plt.plot(x2,y2,color='#0202FF', label='Função escala- DB8')   #Plotando função escala da DB8
plt.grid()
plt.legend()
plt.show()

# %%
#TRANSLAÇÕES DA DB8
         #Phi(x+1)
def DB8escala1(x):
    return DB8escala(x+1)
x14=[-1.0,-0.75,-0.5,-0.25,-0.125,-0.0625,-0.03125,-0.015625,-0.0078125,0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0,1.0078125,1.015625,1.03125,1.0625,1.125,1.25,1.5,1.75,2.0,2.0078125,2.015625,2.03125,2.0625,2.125,2.25,2.5,2.75,3.0,3.0078125,3.015625,3.03125,3.0625,3.125,3.25,3.5,3.75,4.0,4.0078125,4.015625,4.03125,4.0625,4.125,4.25,4.5,4.75,5.0,5.0078125,5.015625,5.03125,5.0625,5.125,5.25,5.5,5.75,6.0]   
y14=[DB8escala1(i) for i in x14]

        #Phi(x+2)
def DB8escala2(x):
    return DB8escala(x+2)
x15=[-2.0,-1.75,-1.50,-1.25,-1.125,-1.0625,-1.03125,-1.015625,-1.0078125,-1.0,-0.75,-0.5,-0.25,-0.125,-0.0625,-0.03125,-0.015625,-0.0078125,0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0,1.0078125,1.015625,1.03125,1.0625,1.125,1.25,1.5,1.75,2.0,2.0078125,2.015625,2.03125,2.0625,2.125,2.25,2.5,2.75,3.0,3.0078125,3.015625,3.03125,3.0625,3.125,3.25,3.5,3.75,4.0,4.0078125,4.015625,4.03125,4.0625,4.125,4.25,4.5,4.75,5.0]  
y15=[DB8escala2(i) for i in x15]

        #Phi(x+3)
def DB8escala3(x):
    return DB8escala(x+3)
x16=[-3.0,-2.75,-2.50,-2.25,-2.125,-2.0625,-2.03125,-2.015625,-2.0078125,-2.0,-1.75,-1.50,-1.25,-1.125,-1.0625,-1.03125,-1.015625,-1.0078125,-1.0,-0.75,-0.5,-0.25,-0.125,-0.0625,-0.03125,-0.015625,-0.0078125,0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0,1.0078125,1.015625,1.03125,1.0625,1.125,1.25,1.5,1.75,2.0,2.0078125,2.015625,2.03125,2.0625,2.125,2.25,2.5,2.75,3.0,3.0078125,3.015625,3.03125,3.0625,3.125,3.25,3.5,3.75,4.0]  
y16=[DB8escala3(i) for i in x16]

        #Phi(x+4)
def DB8escala4(x):
    return DB8escala(x+4)
x17=[-4.0,-3.75,-3.50,-3.25,-3.125,-3.0625,-3.03125,-3.015625,-3.0078125,-3.0,-2.75,-2.50,-2.25,-2.125,-2.0625,-2.03125,-2.015625,-2.0078125,-2.0,-1.75,-1.50,-1.25,-1.125,-1.0625,-1.03125,-1.015625,-1.0078125,-1.0,-0.75,-0.5,-0.25,-0.125,-0.0625,-0.03125,-0.015625,-0.0078125,0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0,1.0078125,1.015625,1.03125,1.0625,1.125,1.25,1.5,1.75,2.0,2.0078125,2.015625,2.03125,2.0625,2.125,2.25,2.5,2.75,3.0]   
y17=[DB8escala4(i) for i in x17]

        #Phi(x+5)
def DB8escala5(x):
    return DB8escala(x+5)
x18=[-5.0,-4.75,-4.50,-4.25,-4.125,-4.0625,-4.03125,-4.015625,-4.0078125,-4.0,-3.75,-3.50,-3.25,-3.125,-3.0625,-3.03125,-3.015625,-3.0078125,-3.0,-2.75,-2.50,-2.25,-2.125,-2.0625,-2.03125,-2.015625,-2.0078125,-2.0,-1.75,-1.50,-1.25,-1.125,-1.0625,-1.03125,-1.015625,-1.0078125,-1.0,-0.75,-0.5,-0.25,-0.125,-0.0625,-0.03125,-0.015625,-0.0078125,0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0,1.0078125,1.015625,1.03125,1.0625,1.125,1.25,1.5,1.75,2.0]   
y18=[DB8escala5(i) for i in x18]

        #Phi(x+6)
def DB8escala6(x):
    return DB8escala(x+6)
x19=[-6.0,-5.75,-5.50,-5.25,-5.125,-5.0625,-5.03125,-5.015625,-5.0078125,-5.0,-4.75,-4.50,-4.25,-4.125,-4.0625,-4.03125,-4.015625,-4.0078125,-4.0,-3.75,-3.50,-3.25,-3.125,-3.0625,-3.03125,-3.015625,-3.0078125,-3.0,-2.75,-2.50,-2.25,-2.125,-2.0625,-2.03125,-2.015625,-2.0078125,-2.0,-1.75,-1.50,-1.25,-1.125,-1.0625,-1.03125,-1.015625,-1.0078125,-1.0,-0.75,-0.5,-0.25,-0.125,-0.0625,-0.03125,-0.015625,-0.0078125,0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0] 
y19=[DB8escala6(i) for i in x19]

        #PLOTAR GRÁFICOS DAS TRANSLAÇÕES DA DB6
import matplotlib.pyplot as plt 
plt.figure(figsize=(8,8))
plt.plot(x2,y2, color='#FF0202', label='DB8escala(x)')   
plt.plot(x14,y14,color='#008000', label='DB8escala(x+1)')   
plt.plot(x15,y15,color='#00468B', label='DB8escala(x+2)')  
plt.plot(x16,y16,color='#5E4800', label='DB8escala(x+3)') 
plt.plot(x17,y17,color='#FFD700', label='DB8escala(x+4)')
plt.plot(x18,y18,color='#C40202', label='DB8escala(x+5)')
plt.plot(x19,y19,color='#0202FF', label='DB8escala(x+6)')
plt.grid()
plt.legend()
plt.show()

#------------------------------GERANDO POLINÔMIO X^3-----------------------------------------------------------

def Polinomiox3(x):
    return x**3
x7=[0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0]    # Comprehenssion list for values of x and y
y71=[Polinomiox3(i) for i in x7]

         #Phi(x) com momento
y20=[0.9073603672021224*DB8escala(i)for i in x7]
          #Phi(x+1) com momento
y21=[-0.1089065333813635*DB8escala1(i) for i in x7]
        #Phi(x+2) com momento
y22=[-1.092814153305344*DB8escala2(i) for i in x7]
        #Phi(x+3) com momento
y23=[-8.044362492569816*DB8escala3(i) for i in x7]
        #Phi(x+4) com momento
y24=[-26.96355155117479*DB8escala4(i) for i in x7]
        #Phi(x+5) com momento
y25=[-63.85038132912025*DB8escala5(i) for i in x7]
        #Phi(x+6) com momento
y26=[-124.7048518264062*DB8escala6(i) for i in x7]


        #Polinômio aproximado
y27=[0.9073603672021224*DB8escala(i)-0.1089065333813635*DB8escala1(i)-1.092814153305344*DB8escala2(i)-8.044362492569816*DB8escala3(i)-26.96355155117479*DB8escala4(i)-63.85038132912025*DB8escala5(i)-124.7048518264062*DB8escala6(i) for i in x7]

plt.figure(figsize=(8,8))
#plt.plot(x7,y71, color='#FF0202', label='x^3')
plt.plot(x7,y20, color='#02ffff', label='0,9073604*DB6escala(x)')   
plt.plot(x7,y21,color='#008000', label='-0,1089065*DB6escala(x+1)')   
plt.plot(x7,y22,color='#00468B', label='-1,092814*DB6escala(x+2)')  
plt.plot(x7,y23,color='#5E4800', label='-8,044362*DB6escala(x+3)') 
plt.plot(x7,y24,color='#FFD700', label='-26,9636*DB6escala(x+4)')
plt.plot(x7,y25,color='#C40202', label='-63,8503*DB6escala(x+5)') 
plt.plot(x7,y26,color='#0202FF', label='-124,7048*DB6escala(x+6)')
plt.plot(x7,y27,color='#FF02FF',label='Função x^3 aproximada por DB 8')
plt.grid()
plt.legend()
plt.show()

# %%
#______DETERMINANDO FUNÇÃO ESCALA DAS DAUBECHIES 4______
import numpy as np  
import matplotlib.pyplot as plt
a=(0.683012701892219,1.183012701892219,0.316987298107781,-0.183012701892219) # Coeficientes de Daubechies de gênero 4
A = np.array(((a[1]-1, a[0]), (1, 1)))
b = np.array((0, 1))       
c  = np.linalg.solve(A, b) #Matriz com os valores de Phi(1),...,Phi(N-2)
def DB4escala(x):
    w4_escalaValor=0
    if (x==3 or x==0):
        return 0
    elif (x==1):
        return c[0]
    elif (x==2):
        return c[1]
    elif (x<0 or x>3):
        return 0
    elif (x>0 and x<3):
        for m in range(0,4):
             w4_escalaValor += a[m]*DB4escala(2*x-m)
        return w4_escalaValor
#______DETERMINANDO TRANSLAÇÕES DA DAUBECHIES 4 (Para 0<x<1)______
def DB4escala1(x):   #Translação Phi(x+1)
    return DB4escala(x+1)
def DB4escala2(x):   #Translação Phi(x+2)
    return DB4escala(x+2)
#______DETERMINANDO APROXIMAÇÃO PARA f(x)=x, COM 0<x<1______
x=[0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0]
y=[0.6339746*DB4escala(i)-0.3660254*DB4escala1(i)-1.3660254*DB4escala2(i) for i in x]


#______ DETERMINANDO FUNÇÃO ESCALA DAS DAUBECHIES 6______
import numpy as np 
import matplotlib.pyplot as plt
l=(0.4704672077841637,1.141116915831444,0.6503650005262326,-0.1909344155683274,-0.1208322083103962,0.04981749973688374) # Coeficientes de Daubechies de gênero 6
L = np.array(((l[1]-1,l[0],0,0), (l[3],l[2]-1,l[1],l[0]), (l[5], l[4], l[3]-1,l[2]),(1,1,1,1))) 
h = np.array((0,0,0,1))
u  = np.linalg.solve(L, h)   #Matriz com os valores de Phi(1),...,Phi(N-2)
def DB6escala(x):
    w6_escalaValor=0
    if (x==5 or x==0):
        return 0
    elif (x==1):
        return u[0]
    elif (x==2):
        return u[1]
    elif (x==3):
        return u[2]
    elif (x==4):
        return u[3]
    elif (x<0 or x>5):
        return 0
    elif (x>0 and x<5):
        for m in range(0,6):
             w6_escalaValor += l[m]*DB6escala(2*x-m)
        return w6_escalaValor
#______DETERMINANDO TRANSLAÇÕES DA DAUBECHIES 6 (Para 0<x<1)______
def DB6escala1(x):         #Phi(x+1)
    return DB6escala(x+1)
def DB6escala2(x):        #Phi(x+2)
    return DB6escala(x+2)
def DB6escala3(x):        #Phi(x+3)
    return DB6escala(x+3)
def DB6escala4(x):        #Phi(x+4)
    return DB6escala(x+4)
#______DETERMINANDO APROXIMAÇÃO PARA f(x)=x², COM 0<x<1______
x2=[0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0]  
y2=[0.6681446691385907*DB6escala(i)+0.03334233351683025*DB6escala1(i)+1.398539997895070*DB6escala2(i)+4.763737662273309*DB6escala3(i)+10.12893532665155*DB6escala4(i) for i in x2]


#______ DETERMINANDO FUNÇÃO ESCALA DAS DAUBECHIES 8______
import numpy as np 
import matplotlib.pyplot as plt
d=(0.3258034280512984,1.010945715091829,0.8922001382467597,-0.03957502623564464,-0.2645071673690398,0.04361630047417725,0.04650360107098176,-0.01498698933036147) # Coeficientes de Daubechies de gênero 8
D = np.array(((d[1]-1,d[0],0,0,0,0), (d[3],d[2]-1,d[1],d[0],0,0), (d[5], d[4], d[3]-1,d[2],d[1],d[0]),(d[7],d[6],d[5],d[4]-1,d[3],d[2]),(0,0,d[7],d[6],d[5]-1,d[4]),(1,1,1,1,1,1)))
f = np.array((0,0,0,0,0,1))
g  = np.linalg.solve(D, f)
def DB8escala(x):
    w8_escalaValor=0
    if (x==7 or x==0):
        return 0
    elif (x==1):
        return g[0]
    elif (x==2):
        return g[1]
    elif (x==3):
        return g[2]
    elif (x==4):
        return g[3]
    elif (x==5):
        return g[4]
    elif (x==6):
        return g[5]
    elif (x<0 or x>7):
        return 0
    elif (x>0 and x<7):
        for m in range(0,8):
             w8_escalaValor += d[m]*DB8escala(2*x-m)
        return w8_escalaValor
#______DETERMINANDO TRANSLAÇÕES DA DAUBECHIES 8 (Para 0<x<1)______
def DB8escala1(x):         #Phi(x+1)
    return DB8escala(x+1)
def DB8escala2(x):        #Phi(x+2)
    return DB8escala(x+2)
def DB8escala3(x):        #Phi(x+3)
    return DB8escala(x+3)
def DB8escala4(x):        #Phi(x+4)
    return DB8escala(x+4)
def DB8escala5(x):        #Phi(x+5)
    return DB8escala(x+5)
def DB8escala6(x):        #Phi(x+6)
    return DB8escala(x+6)

    
#______DETERMINANDO APROXIMAÇÃO PARA f(x)=x³, COM 0<x<1______
x3=[0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0]  
y3=[0.9073603672021224*DB8escala(i)-0.1089065333813635*DB8escala1(i)-1.092814153305344*DB8escala2(i)-8.044362492569816*DB8escala3(i)-26.96355155117479*DB8escala4(i)-63.85038132912025*DB8escala5(i)-124.7048518264062*DB8escala6(i) for i in x]

#______DETERMINANDO APROXIMAÇÃO PARA f(x)=e^x, sen(x) E cos(x) COM 0<x<1______
x4=[0.0,0.0078125,0.015625,0.03125,0.0625,0.125,0.25,0.5,0.75,1.0]  
y4=[1+0.6339746*DB4escala(i)-0.3660254*DB4escala1(i)-1.3660254*DB4escala2(i)+0.5*0.6681446691385907*DB6escala(i)+0.5*0.03334233351683025*DB6escala1(i)+0.5*1.398539997895070*DB6escala2(i)+0.5*4.763737662273309*DB6escala3(i)+0.5*10.12893532665155*DB6escala4(i)+0.166666*0.9073603672021224*DB8escala(i)-0.166666*0.1089065333813635*DB8escala1(i)-0.166666*1.092814153305344*DB8escala2(i)-0.166666*8.044362492569816*DB8escala3(i)-0.166666*26.96355155117479*DB8escala4(i)-0.166666*63.85038132912025*DB8escala5(i)-0.166666*124.7048518264062*DB8escala6(i) for i in x4]
y5=[0.6339746*DB4escala(i)-0.3660254*DB4escala1(i)-1.3660254*DB4escala2(i)-1.66666*0.9073603672021224*DB8escala(i)+1.66666*0.1089065333813635*DB8escala1(i)+1.66666*1.092814153305344*DB8escala2(i)+1.66666*8.044362492569816*DB8escala3(i)+0.166666*26.96355155117479*DB8escala4(i)+0.166666*63.85038132912025*DB8escala5(i)+0.166666*124.7048518264062*DB8escala6(i) for i in x4]
y6=[0.6339746*DB4escala(i)-0.3660254*DB4escala1(i)-1.3660254*DB4escala2(i)-0.5*0.6681446691385907*DB6escala(i)-0.5*0.03334233351683025*DB6escala1(i)-0.5*1.398539997895070*DB6escala2(i)-0.5*4.763737662273309*DB6escala3(i)-0.5*10.12893532665155*DB6escala4(i) for i in x4]

#3x + e^x
x7=[0.0,0.015625,0.03125,0.0625,0.125,0.25,0.28125,0.375,0.5]  
y7=[3*0.6339746*DB4escala(i)-3*0.3660254*DB4escala1(i)-3*1.3660254*DB4escala2(i)+1+0.6339746*DB4escala(i)-0.3660254*DB4escala1(i)-1.3660254*DB4escala2(i)+0.5*0.6681446691385907*DB6escala(i)+0.5*0.03334233351683025*DB6escala1(i)+0.5*1.398539997895070*DB6escala2(i)+0.5*4.763737662273309*DB6escala3(i)+0.5*10.12893532665155*DB6escala4(i)+0.166666*0.9073603672021224*DB8escala(i)-0.166666*0.1089065333813635*DB8escala1(i)-0.166666*1.092814153305344*DB8escala2(i)-0.166666*8.044362492569816*DB8escala3(i)-0.166666*26.96355155117479*DB8escala4(i)-1.66666*63.85038132912025*DB8escala5(i)-1.66666*124.7048518264062*DB8escala6(i) for i in x7]
#3x + e^(-0.5x)
x8=[0.5,0.53125,0.5625,0.625,0.703125,0.75,0.78125,0.828125,0.875,1.0]  
y8=[3*0.6339746*DB4escala(i)-3*0.3660254*DB4escala1(i)-3*1.3660254*DB4escala2(i)+1-0.5*0.6339746*DB4escala(i)+0.5*0.3660254*DB4escala1(i)+0.5*1.3660254*DB4escala2(i)+0.125*0.6681446691385907*DB6escala(i)+0.125*0.03334233351683025*DB6escala1(i)+0.125*1.398539997895070*DB6escala2(i)+0.125*4.763737662273309*DB6escala3(i)+0.125*10.12893532665155*DB6escala4(i)-0.125*0.166666*0.9073603672021224*DB8escala(i)+0.125*0.166666*0.1089065333813635*DB8escala1(i)+0.125*0.166666*1.092814153305344*DB8escala2(i)+0.125*0.166666*8.044362492569816*DB8escala3(i)+0.125*0.166666*26.96355155117479*DB8escala4(i)+0.125*0.166666*63.85038132912025*DB8escala5(i)+0.125*0.166666*124.7048518264062*DB8escala6(i) for i in x8]

plt.figure(figsize=(8,8))
plt.plot(x4,y4,color='#FF02FF',label='e^x aproximado por daubechies com 4 termos da série de Taylor')
#plt.plot(x4,y5,color='#FF02FF',label='sen(x) aproximado por daubechies com 2 termos da série de Taylor')
#plt.plot(x4,y6,color='#FF02FF',label='cos(x) aproximado por daubechies com 2 termos da série de Taylor')
#plt.plot(x7,y7,color='#02ffff')#,label='f(x)=3x+e^x aproximado por Daubechies')
#plt.plot(x8,y8,color='#FF02FF')#,label='f(x)=3x+e^(-0.5x) aproximado por Daubechies')
plt.grid()
plt.legend()
plt.show()
